# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, encoding='latin-1')
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN      PORTO ALEGRE            RS
# 1    -234.355.555.556     -464.730.555.556         GUARULHOS            SP
# 2                 ***                  ***            VIAMÃO            RS
# 3                 ***                  ***     SÃO SEBASTIÃO            SP
# 4                 ***                  ***          SÃO SEPÉ            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2012-01-05        20:27:00                            ***
# 1  ...     2012-01-06        13:44:00                            SIM
# 2  ...     2012-01-06        13:00:00                            NaN
# 3  ...     2012-01-06        17:00:00                            ***
# 4  ...     2012-01-06        16:30:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA           A-582/CENIPA/2014
# 2          FINALIZADA           A-070/CENIPA/2013
# 3                 NaN                         NaN
# 4          FINALIZADA           A-071/CENIPA/2013
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            SIM                01/09/2016
# 2                            SIM                27/11/2013
# 3                            NÃO                       NaN
# 4                            SIM                27/11/2013
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   3                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              45332               45332               45332
# 40              45415               45415               45415
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               45332               45332                 ACIDENTE
# 40               45415               45415                 ACIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 ***                  ***            VIAMÃO            RS
# 40                 ***                  ***    RIO DE JANEIRO            RJ
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2012-01-09        13:30:00                            SIM
# 40  ...     2012-01-30        13:55:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10          FINALIZADA           A-072/CENIPA/2013
# 40          FINALIZADA           A-077/CENIPA/2013
#
#    divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 10                            SIM                27/11/2013
# 40                            SIM                21/10/2013
#
#    total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 10                   0                          1                     NÃO
# 40                   0                          1                     NÃO
#
# [2 rows x 22 columns]

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 52242                           52242               52242               52242
# 45331                           45331               45331               45331
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade  \
# codigo_ocorrencia
# 52242                             NaN                  NaN      PORTO ALEGRE
# 45331                -234.355.555.556     -464.730.555.556         GUARULHOS
# 45333                             ***                  ***            VIAMÃO
# 45401                             ***                  ***     SÃO SEBASTIÃO
# 45407                             ***                  ***          SÃO SEPÉ
#
#                   ocorrencia_uf ocorrencia_pais  ... ocorrencia_dia  \
# codigo_ocorrencia                                ...
# 52242                        RS          BRASIL  ...     2012-01-05
# 45331                        SP          BRASIL  ...     2012-01-06
# 45333                        RS          BRASIL  ...     2012-01-06
# 45401                        SP          BRASIL  ...     2012-01-06
# 45407                        RS          BRASIL  ...     2012-01-06
#
#                   ocorrencia_hora investigacao_aeronave_liberada  \
# codigo_ocorrencia
# 52242                    20:27:00                            ***
# 45331                    13:44:00                            SIM
# 45333                    13:00:00                            NaN
# 45401                    17:00:00                            ***
# 45407                    16:30:00                            SIM
#
#                   investigacao_status divulgacao_relatorio_numero  \
# codigo_ocorrencia
# 52242                      FINALIZADA                         ***
# 45331                      FINALIZADA           A-582/CENIPA/2014
# 45333                      FINALIZADA           A-070/CENIPA/2013
# 45401                             NaN                         NaN
# 45407                      FINALIZADA           A-071/CENIPA/2013
#
#                   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# codigo_ocorrencia
# 52242                                        NÃO                       NaN
# 45331                                        SIM                01/09/2016
# 45333                                        SIM                27/11/2013
# 45401                                        NÃO                       NaN
# 45407                                        SIM                27/11/2013
#
#                   total_recomendacoes  total_aeronaves_envolvidas  \
# codigo_ocorrencia
# 52242                               0                           1
# 45331                               3                           1
# 45333                               0                           1
# 45401                               0                           1
# 45407                               0                           1
#
#                    ocorrencia_saida_pista
# codigo_ocorrencia
# 52242                                 NÃO
# 45331                                 NÃO
# 45333                                 NÃO
# 45401                                 NÃO
# 45407                                 NÃO
#
# [5 rows x 21 columns]

# %%
df.loc[45407]
# Out:
# codigo_ocorrencia1                              45407
# codigo_ocorrencia2                              45407
# codigo_ocorrencia3                              45407
# codigo_ocorrencia4                              45407
# ocorrencia_classificacao                     ACIDENTE
# ocorrencia_latitude                               ***
# ocorrencia_longitude                              ***
# ocorrencia_cidade                            SÃO SEPÉ
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             ****
# ocorrencia_dia                    2012-01-06 00:00:00
# ocorrencia_hora                              16:30:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero         A-071/CENIPA/2013
# divulgacao_relatorio_publicado                    SIM
# divulgacao_dia_publicacao                  27/11/2013
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 45407, dtype: object

# %%
df.reset_index(drop=True, inplace=True )

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
# 1               45331                 ACIDENTE    -234.355.555.556
# 2               45333                 ACIDENTE                 ***
# 3               45401                 ACIDENTE                 ***
# 4               45407                 ACIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
# 1     -464.730.555.556         GUARULHOS            SP          BRASIL  ...
# 2                  ***            VIAMÃO            RS          BRASIL  ...
# 3                  ***     SÃO SEBASTIÃO            SP          BRASIL  ...
# 4                  ***          SÃO SEPÉ            RS          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2012-01-05        20:27:00                            ***
# 1     2012-01-06        13:44:00                            SIM
# 2     2012-01-06        13:00:00                            NaN
# 3     2012-01-06        17:00:00                            ***
# 4     2012-01-06        16:30:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA           A-582/CENIPA/2014
# 2          FINALIZADA           A-070/CENIPA/2013
# 3                 NaN                         NaN
# 4          FINALIZADA           A-071/CENIPA/2013
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            SIM                01/09/2016
# 2                            SIM                27/11/2013
# 3                            NÃO                       NaN
# 4                            SIM                27/11/2013
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                   3                           1                     NÃO
# 2                   0                           1                     NÃO
# 3                   0                           1                     NÃO
# 4                   0                           1                     NÃO
#
# [5 rows x 21 columns]

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2012-01-05        20:27:00                            ***
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
#
# [1 rows x 21 columns]

# %%
df.loc[1]=20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2012-01-05 00:00:00        20:27:00                            ***
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1                  20                          20
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                             20                        20
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                  20                          20                      20
#
# [2 rows x 21 columns]

# %%
df.loc[:,'total_recomendacoes'] = 10

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  52242               52242               52242
# 1                     20                  20                  20
# 2                  45333               45333               45333
# 3                  45401               45401               45401
# 4                  45407               45407               45407
# ...                  ...                 ...                 ...
# 5162               80458               80458               80458
# 5163               80452               80452               80452
# 5164               80457               80457               80457
# 5165               80460               80460               80460
# 5166               80467               80467               80467
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  52242                INCIDENTE                 NaN
# 1                     20                       20                  20
# 2                  45333                 ACIDENTE                 ***
# 3                  45401                    GRAVE                 ***
# 4                  45407                 ACIDENTE                 ***
# ...                  ...                      ...                 ...
# 5162               80458                 ACIDENTE         -17.999.194
# 5163               80452                    GRAVE         -22.585.556
# 5164               80457          INCIDENTE GRAVE         -29.695.833
# 5165               80460                INCIDENTE         -25.403.333
# 5166               80467                INCIDENTE             -93.675
#
#      ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 0                     NaN      PORTO ALEGRE            RS          BRASIL
# 1                      20                20            20              20
# 2                     ***            VIAMÃO            RS          BRASIL
# 3                     ***     SÃO SEBASTIÃO            SP          BRASIL
# 4                     ***          SÃO SEPÉ            RS          BRASIL
# ...                   ...               ...           ...             ...
# 5162          -51.642.861             JATAÍ            GO          BRASIL
# 5163          -50.753.889           MARACAÍ            SP          BRASIL
# 5164          -51.081.667     NOVO HAMBURGO            RS          BRASIL
# 5165          -49.233.611          CURITIBA            PR          BRASIL
# 5166   -4.056.361.111.111         PETROLINA            PE          BRASIL
#
#       ... ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0     ...        20:27:00                            ***          FINALIZADA
# 1     ...              20                             20                  20
# 2     ...        13:00:00                            NaN          FINALIZADA
# 3     ...        17:00:00                            ***                 NaN
# 4     ...        16:30:00                            SIM          FINALIZADA
# ...   ...             ...                            ...                 ...
# 5162  ...        20:30:00                            SIM               ATIVA
# 5163  ...        09:30:00                            SIM               ATIVA
# 5164  ...        11:59:00                            SIM          FINALIZADA
# 5165  ...        15:12:00                            SIM          FINALIZADA
# 5166  ...        20:30:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                             20                             20
# 2              A-070/CENIPA/2013                            SIM
# 3                            NaN                            NÃO
# 4              A-071/CENIPA/2013                            SIM
# ...                          ...                            ...
# 5162                   A DEFINIR                            NÃO
# 5163                   A DEFINIR                            NÃO
# 5164                         ***                            NÃO
# 5165                         ***                            NÃO
# 5166                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                  10                          1
# 1                           20                  10                         20
# 2                   27/11/2013                  10                          1
# 3                          NaN                  10                          1
# 4                   27/11/2013                  10                          1
# ...                        ...                 ...                        ...
# 5162                       NaN                  10                          1
# 5163                       NaN                  10                          1
# 5164                       NaN                  10                          1
# 5165                       NaN                  10                          1
# 5166                       NaN                  10                          1
#
#       ocorrencia_saida_pista  ocorrencia_uf_bkp
# 0                        NÃO                 RS
# 1                         20                 20
# 2                        NÃO                 RS
# 3                        NÃO                 SP
# 4                        NÃO                 RS
# ...                      ...                ...
# 5162                     NÃO                 GO
# 5163                     NÃO                 SP
# 5164                     NÃO                 RS
# 5165                     NÃO                 PR
# 5166                     NÃO                 PE
#
# [5167 rows x 22 columns]

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 3                  45401               45401               45401
# 5                  52243               52243               52243
# 6                  50713               50713               50713
# 13                 45408               45408               45408
# 26                 45410               45410               45410
# ...                  ...                 ...                 ...
# 5148               80441               80441               80441
# 5157               80453               80453               80453
# 5158               80454               80454               80454
# 5161               80456               80456               80456
# 5163               80452               80452               80452
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 3                  45401                    GRAVE                 ***
# 5                  52243                    GRAVE                 NaN
# 6                  50713                    GRAVE                 ***
# 13                 45408                    GRAVE    -245.888.888.889
# 26                 45410                    GRAVE         -23.005.278
# ...                  ...                      ...                 ...
# 5148               80441                    GRAVE            -230.052
# 5157               80453                    GRAVE  -2.300.694.444.444
# 5158               80454                    GRAVE         -21.144.167
# 5161               80456                    GRAVE         -23.626.111
# 5163               80452                    GRAVE         -22.585.556
#
#      ocorrencia_longitude  ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 3                     ***      SÃO SEBASTIÃO            SP          BRASIL
# 5                     NaN            UBATUBA            SP          BRASIL
# 6                     ***           CAMPINAS            SP          BRASIL
# 13       -482.113.888.889           ELDORADO            SP          BRASIL
# 26            -46.636.944  BRAGANÇA PAULISTA            SP          BRASIL
# ...                   ...                ...           ...             ...
# 5148             -466.336  BRAGANÇA PAULISTA            SP          BRASIL
# 5157   -4.713.444.444.444           CAMPINAS            SP          BRASIL
# 5158          -50.426.389          ARAÇATUBA            SP          BRASIL
# 5161          -46.656.389          SÃO PAULO            SP          BRASIL
# 5163          -50.753.889            MARACAÍ            SP          BRASIL
#
#       ... ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 3     ...        17:00:00                            ***                 NaN
# 5     ...        14:30:00                            ***          FINALIZADA
# 6     ...        18:15:00                            SIM          FINALIZADA
# 13    ...        13:45:00                            SIM          FINALIZADA
# 26    ...        23:30:00                            ***          FINALIZADA
# ...   ...             ...                            ...                 ...
# 5148  ...        18:15:00                            NÃO               ATIVA
# 5157  ...        09:00:00                            SIM          FINALIZADA
# 5158  ...        21:35:00                            SIM          FINALIZADA
# 5161  ...        13:15:00                            SIM          FINALIZADA
# 5163  ...        09:30:00                            SIM               ATIVA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 3                            NaN                            NÃO
# 5                            ***                            NÃO
# 6             IG-184/CENIPA/2013                            SIM
# 13             A-509/CENIPA/2021                            SIM
# 26                     A DEFINIR                            NÃO
# ...                          ...                            ...
# 5148                   A DEFINIR                            NÃO
# 5157                         ***                            NÃO
# 5158                         ***                            NÃO
# 5161                         ***                            NÃO
# 5163                   A DEFINIR                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 3                          NaN                  10                          1
# 5                          NaN                  10                          1
# 6                   08/01/2014                  10                          1
# 13                  08/07/2021                  10                          1
# 26                         NaN                  10                          1
# ...                        ...                 ...                        ...
# 5148                       NaN                  10                          1
# 5157                       NaN                  10                          1
# 5158                       NaN                  10                          1
# 5161                       NaN                  10                          1
# 5163                       NaN                  10                          1
#
#       ocorrencia_saida_pista  ocorrencia_uf_bkp
# 3                        NÃO                 SP
# 5                        NÃO                 SP
# 6                        NÃO                 SP
# 13                       NÃO                 SP
# 26                       SIM                 SP
# ...                      ...                ...
# 5148                     SIM                 SP
# 5157                     NÃO                 SP
# 5158                     SIM                 SP
# 5161                     SIM                 SP
# 5163                     NÃO                 SP
#
# [1260 rows x 22 columns]

# %% [raw]
# ocorrencia_latitude
# \t
# ***
# ****
# *********
# ocorrencia_longitude
# \t
# ***
# ****
# *********
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL
# investigacao_aeronave_liberada
# NULL
# ***
# divulgacao_relatorio_numero
# ***
# NULL
# divulgacao_dia_publicacao
# NULL

# %%
df.head()

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA
