# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['\t','**','***','****','*****','###!','####','NaN','NULL']
df = pd.read_csv(encoding='latin-1', "ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0            52242.0             52242.0             52242.0
# 1            45331.0             45331.0             45331.0
# 2            45333.0             45333.0             45333.0
# 3            45401.0             45401.0             45401.0
# 4            45407.0             45407.0             45407.0
# 5            52243.0             52243.0             52243.0
# 6            50713.0             50713.0             50713.0
# 7            45334.0             45334.0             45334.0
# 8            45391.0             45391.0             45391.0
# 9            52244.0             52244.0             52244.0
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0             52242.0             52242.0                INCIDENTE
# 1             45331.0             45331.0                 ACIDENTE
# 2             45333.0             45333.0                 ACIDENTE
# 3             45401.0             45401.0                 ACIDENTE
# 4             45407.0             45407.0                 ACIDENTE
# 5             52243.0             52243.0                INCIDENTE
# 6             50713.0             50713.0          INCIDENTE GRAVE
# 7             45334.0             45334.0                INCIDENTE
# 8             45391.0             45391.0                 ACIDENTE
# 9             52244.0             52244.0                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 0                 NaN                  NaN           PORTO ALEGRE
# 1    -234.355.555.556     -464.730.555.556              GUARULHOS
# 2                 ***                  ***                 VIAMÃO
# 3                 ***                  ***          SÃO SEBASTIÃO
# 4                 ***                  ***               SÃO SEPÉ
# 5                 NaN                  NaN                UBATUBA
# 6                 ***                  ***               CAMPINAS
# 7                 NaN                  NaN                  BELÉM
# 8    -199.133.333.333     -482.930.555.556  CONCEIÇÃO DAS ALAGOAS
# 9                 ***                  ***             UBERLÂNDIA
#
#   ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0            RS  ...     2012-01-05        20:27:00
# 1            SP  ...     2012-01-06        13:44:00
# 2            RS  ...     2012-01-06        13:00:00
# 3            SP  ...     2012-01-06        17:00:00
# 4            RS  ...     2012-01-06        16:30:00
# 5            SP  ...     2012-01-06        14:30:00
# 6            SP  ...     2012-01-07        18:15:00
# 7            PA  ...     2012-01-08        19:12:00
# 8            MG  ...     2012-01-08        16:00:00
# 9            MG  ...     2012-01-08        22:13:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            ***          FINALIZADA
# 1                            SIM          FINALIZADA
# 2                            NaN          FINALIZADA
# 3                            ***                 NaN
# 4                            SIM          FINALIZADA
# 5                            ***          FINALIZADA
# 6                            SIM          FINALIZADA
# 7                            ***          FINALIZADA
# 8                            ***          FINALIZADA
# 9                            ***          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1           A-582/CENIPA/2014                            SIM
# 2           A-070/CENIPA/2013                            SIM
# 3                         NaN                            NÃO
# 4           A-071/CENIPA/2013                            SIM
# 5                         ***                            NÃO
# 6          IG-184/CENIPA/2013                            SIM
# 7                         ***                            NÃO
# 8                   A DEFINIR                            NÃO
# 9                         ***                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                 0.0                        1.0
# 1                01/09/2016                 3.0                        1.0
# 2                27/11/2013                 0.0                        1.0
# 3                       NaN                 0.0                        1.0
# 4                27/11/2013                 0.0                        1.0
# 5                       NaN                 0.0                        1.0
# 6                08/01/2014                 0.0                        1.0
# 7                       NaN                 0.0                        1.0
# 8                       NaN                 0.0                        1.0
# 9                       NaN                 0.0                        1.0
#
#    ocorrencia_saida_pista
# 0                     NÃO
# 1                     NÃO
# 2                     NÃO
# 3                     NÃO
# 4                     NÃO
# 5                     NÃO
# 6                     NÃO
# 7                     NÃO
# 8                     NÃO
# 9                     NÃO
#
# [10 rows x 22 columns]

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo":pa.Column(pa.String),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
